# %% [markdown]
# ### Compute grand truth driver node sets
#
# For large models, computation can be time-consuming. Therefore, it is recommended to compute the driver node sets individually for each model.

# %%
from tools.ground_truth_control import compute_ground_truth_control_sets

# %%
str_base_dir="../datasets/targets_test/"
str_store_dir='./summary_csv_test/'

compute_ground_truth_control_sets(str_base_dir=str_base_dir, str_store_dir=str_store_dir)
# Out:
# Target .txt files found: 12
# Final model_paths count: 12
# Get model paths
#
# Start compute ground truth driver node sets
#
# A thaliana cell type determination root stem cell niche gene regulatory network kadelkastart
# Input nodes
# 2
# Asymmetric Cell Division in Caulobacter Crescentus A ginsimstart
# Input nodes
# 0
# Asymmetric Cell Division in Caulobacter Crescentus B ginsimstart
# Input nodes
# 0
# C. elegans early embryonic cell cycles kadelkastart
# Input nodes
# 0
# Cell Cycle Transcription by Coupled CDK and Network Oscillatorsstart
# Input nodes
# 0
# Cortical Area Developmentstart
# Input nodes
# 0
# Epithelial-to-mesenchymal transition kadelkastart
# Input nodes
# 1
# Immune Surveillance Tumor Immunity and Cancer kadelkastart
# Input nodes
# 0
# Mammalian Cell Cycle 2006start
# Input nodes
# 1
# Spontaneous Immortalization and Epithelial Mesenchymal Transition kadelkastart
# Input nodes
# 0
# The Pseudomonas syringae hrp Regulon kadelkastart
# Input nodes
# 1
# The Saccharomyces cerevisiae cell cycle kadelkastart
# Input nodes
# 0

# %% [markdown]
# ### Compute structural control node sets

# %%
from tools.structural_control import compute_structural_control_nodes

# %%
str_summary_dir='./summary_csv_test/'
str_store_dir='./structural_driver_summary_by_test/'

compute_structural_control_nodes(
    str_base_dir=str_base_dir, str_summary_dir=str_summary_dir, str_store_dir=str_store_dir)
# Out:
# Target .txt files found: 12
# Final model_paths count: 12
# Get model paths
#
# Start compute structural control nodes FVS, MDS, SC
#
# A thaliana cell type determination root stem cell niche gene regulatory network kadelkastart
# Asymmetric Cell Division in Caulobacter Crescentus A ginsimstart
# Asymmetric Cell Division in Caulobacter Crescentus B ginsimstart
# C. elegans early embryonic cell cycles kadelkastart
# Cell Cycle Transcription by Coupled CDK and Network Oscillatorsstart
# Cortical Area Developmentstart
# Epithelial-to-mesenchymal transition kadelkastart
# Immune Surveillance Tumor Immunity and Cancer kadelkastart
# Mammalian Cell Cycle 2006start
# Spontaneous Immortalization and Epithelial Mesenchymal Transition kadelkastart
# The Pseudomonas syringae hrp Regulon kadelkastart
# The Saccharomyces cerevisiae cell cycle kadelkastart
#
# Complete compute structural control nodes FVS, MDS, SC

# %% [markdown]
# ### Visualize comparisons between ground truth and structural control node sets

# %%
from tools.control_sets_comparison import visualize_structural_control_nodes_vs_ground_truth

# %%
str_reference_path='./structural_driver_summary_by_test/'
similarity_type="Jaccard" # Either "Jaccard", "Overshoot", or "Undershoot"
summary_type="mean" # Either "mean", "max", or "min"
nrows=3
ncols=4
max_observations=15 # Maximum number of edge effectiveness threshold observations
visualize_structural_control_nodes_vs_ground_truth(str_reference_path, similarity_type, summary_type, nrows, ncols, max_observations)
# Out:
# Found 12 model directories.
# <module 'matplotlib.pyplot' from 'C:\\Users\\17859\\miniforge3\\envs\\cana_2026\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
str_reference_path='./structural_driver_summary_by_test/'
similarity_type="Jaccard"
summary_type="max"

visualize_structural_control_nodes_vs_ground_truth(str_reference_path, similarity_type, summary_type, nrows, ncols, max_observations)
# Out:
# Found 12 model directories.
# <module 'matplotlib.pyplot' from 'C:\\Users\\17859\\miniforge3\\envs\\cana_2026\\Lib\\site-packages\\matplotlib\\pyplot.py'>
