# %% [markdown]
# ## Compare actionability between grand truth driver nodes and non-driver nodes

# %% [markdown]
# ### Compute grand truth driver node sets
#
# For large models, computation can be time-consuming. Therefore, it is recommended to compute the driver node sets individually for each model.

# %%
from tools.ground_truth_control import compute_ground_truth_control_sets

# %%
str_base_dir="../datasets/targets_test/"
str_store_dir='./summary_csv_test/'

compute_ground_truth_control_sets(str_base_dir=str_base_dir, str_store_dir=str_store_dir)
# Out:
# Target .txt files found: 12
# Final model_paths count: 12
# Get model paths
#
# Start compute ground truth driver node sets
#
# A thaliana cell type determination root stem cell niche gene regulatory network kadelkastart
# Input nodes
# 2
# Asymmetric Cell Division in Caulobacter Crescentus A ginsimstart
# Input nodes
# 0
# Asymmetric Cell Division in Caulobacter Crescentus B ginsimstart
# Input nodes
# 0
# C. elegans early embryonic cell cycles kadelkastart
# Input nodes
# 0
# Cell Cycle Transcription by Coupled CDK and Network Oscillatorsstart
# Input nodes
# 0
# Cortical Area Developmentstart
# Input nodes
# 0
# Epithelial-to-mesenchymal transition kadelkastart
# Input nodes
# 1
# Immune Surveillance Tumor Immunity and Cancer kadelkastart
# Input nodes
# 0
# Mammalian Cell Cycle 2006start
# Input nodes
# 1
# Spontaneous Immortalization and Epithelial Mesenchymal Transition kadelkastart
# Input nodes
# 0
# The Pseudomonas syringae hrp Regulon kadelkastart
# Input nodes
# 1
# The Saccharomyces cerevisiae cell cycle kadelkastart
# Input nodes
# 0

# %% [markdown]
# ### Compute Node- and Edge- level actionability per node

# %%
from tools.actionability import actionability_per_node

# %%
# Define directories using pathlib.Path for cross-platform compatibility
str_summary_dir = "./summary_csv_test/" # Directory in which model summary (node information) files are stored
str_store_dir = "./actionability_summary/"      # Directory to which actionability computation results are stored
process_type = "Both"                           # Edge- and Node- level actionability are computed

actionability_per_node(str_base_dir, str_summary_dir, str_store_dir, process_type)
# Out:
# Found 12 text files in ..\datasets\targets_test
#
# Store directory actionability_summary\Both already exists.
# [A thaliana cell type determination root stem cell niche gene regulatory network kadelka] Computing Node Actionability...
# [A thaliana cell type determination root stem cell niche gene regulatory network kadelka] Computing Edge Actionability...
# [Asymmetric Cell Division in Caulobacter Crescentus A ginsim] Computing Node Actionability...
# [Asymmetric Cell Division in Caulobacter Crescentus A ginsim] Computing Edge Actionability...
# [Asymmetric Cell Division in Caulobacter Crescentus B ginsim] Computing Node Actionability...
# [Asymmetric Cell Division in Caulobacter Crescentus B ginsim] Computing Edge Actionability...
# [C. elegans early embryonic cell cycles kadelka] Computing Node Actionability...
# [C. elegans early embryonic cell cycles kadelka] Computing Edge Actionability...
# [Cell Cycle Transcription by Coupled CDK and Network Oscillators] Computing Node Actionability...
# [Cell Cycle Transcription by Coupled CDK and Network Oscillators] Computing Edge Actionability...
# [Cortical Area Development] Computing Node Actionability...
# [Cortical Area Development] Computing Edge Actionability...
# [Epithelial-to-mesenchymal transition kadelka] Computing Node Actionability...
# [Epithelial-to-mesenchymal transition kadelka] Computing Edge Actionability...
# [Immune Surveillance Tumor Immunity and Cancer kadelka] Computing Node Actionability...
# [Immune Surveillance Tumor Immunity and Cancer kadelka] Computing Edge Actionability...
# [Mammalian Cell Cycle 2006] Computing Node Actionability...
# [Mammalian Cell Cycle 2006] Computing Edge Actionability...
# [Spontaneous Immortalization and Epithelial Mesenchymal Transition kadelka] Computing Node Actionability...
# [Spontaneous Immortalization and Epithelial Mesenchymal Transition kadelka] Computing Edge Actionability...
# [The Pseudomonas syringae hrp Regulon kadelka] Computing Node Actionability...
# [The Pseudomonas syringae hrp Regulon kadelka] Computing Edge Actionability...
# [The Saccharomyces cerevisiae cell cycle kadelka] Computing Node Actionability...
# [The Saccharomyces cerevisiae cell cycle kadelka] Computing Edge Actionability...

# %% [markdown]
# ### Aggregate all models actionability data

# %%
from tools.actionability import aggregate_actionability_summary

# %%
str_source_dir = "./actionability_summary/Both/" 

df_actionability_all = aggregate_actionability_summary(str_source_dir)
# Out:
# Found 12 text files in actionability_summary\Both
#
# Aggregated 12 files. Total rows: 186

# %%
df_actionability_all
# Out:
#                                            source_file  node_id node_name  \
# 0    actionability_summary\Both\A thaliana cell typ...        0       PLT
# 1    actionability_summary\Both\A thaliana cell typ...        0       PLT
# 2    actionability_summary\Both\A thaliana cell typ...        1    AUXINS
# 3    actionability_summary\Both\A thaliana cell typ...        1    AUXINS
# 4    actionability_summary\Both\A thaliana cell typ...        2       IAA
# ..                                                 ...      ...       ...
# 181  actionability_summary\Both\The Saccharomyces c...        6      YHP1
# 182  actionability_summary\Both\The Saccharomyces c...        7       SBF
# 183  actionability_summary\Both\The Saccharomyces c...        7       SBF
# 184  actionability_summary\Both\The Saccharomyces c...        8      CLN3
# 185  actionability_summary\Both\The Saccharomyces c...        8      CLN3
#
#     driver_node   node_role  condition_state  IG_nodes  IG_edges  E_redundant  \
# 0    non-driver  inner node                0         9        19            0
# 1    non-driver  inner node                1         9        19            0
# 2        driver  input node                0         9        19            4
# 3        driver  input node                1         9        19            0
# 4    non-driver  inner node                0         9        19            0
# ..          ...         ...              ...       ...       ...          ...
# 181  non-driver  inner node                1         9        19            9
# 182  non-driver  inner node                0         9        19            6
# 183  non-driver  inner node                1         9        19            7
# 184      driver  inner node                0         9        19            6
# 185      driver  inner node                1         9        19            7
#
#      E_ON  E_OFF  edge_actionability  N_OFF  N_ON  node_actionability
# 0       0      0              1.0000      0     0               1.000
# 1       0      0              1.0000      0     0               1.000
# 2       1      5              0.4737      3     1               0.500
# 3       4      1              0.7368      1     2               0.625
# 4       2      1              0.8421      0     2               0.750
# ..    ...    ...                 ...    ...   ...                 ...
# 181     2      8              0.0000      8     0               0.000
# 182     0     13              0.0000      8     0               0.000
# 183     6      6              0.0000      7     1               0.000
# 184     0     13              0.0000      8     0               0.000
# 185     7      5              0.0000      6     2               0.000
#
# [186 rows x 15 columns]

# %% [markdown]
# ### Edge actionability analysis

# %%
from tools.control_sets_comparison import actionability_per_node_boxplot

# %%
analysis_level="Edge"
actionability_per_node_boxplot(df_actionability_all=df_actionability_all, analysis_level=analysis_level)

# %% [markdown]
# ### Node actionability analysis

# %%
analysis_level="Node"
actionability_per_node_boxplot(df_actionability_all=df_actionability_all, analysis_level=analysis_level)
